# %% [markdown]
# <a href="https://colab.research.google.com/github/fabizap/Olist/blob/main/BASES_7_Y_8_DE_FABIAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # SEPTIMA DATAFRAME: PRODUCTS.
# ---
# VARIABLES:
# >product_id: identificador único de producto. unique product identifier
#
# >product_category_name: categoría raíz del producto en portugués. root category of product, in Portuguese.
#
# >product_name_lenght: número de caracteres extraídos del nombre del producto number of characters extracted from the product name.
#
# >product_description_lenght: Número de caracteres extraídos de la descripción del producto. number of characters extracted from the product description.
#
# >product_photos_qty: número de fotos publicadas del producto. number of product published photos
#
# >product_weight_g: peso del producto medido en gramos. product weight measured in grams.
#
# >product_length_cm: Longitud del producto medida en centímetros. product length measured in centimeters.
#
# >product_height_cm: Altura del producto medida en centímetros. product height measured in centimeters.
#
# >product_width_cm: Ancho del producto medida en centímetros. product width measured in centimeters.
#
# ---

# %%
url7='https://raw.githubusercontent.com/fabizap/Olist/main/olist_products_dataset.csv'
df7=pd.read_csv(url7)
df7.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df7.shape
# Out:
# (32951, 9)

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df7.describe().round(2)
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count             32341.00                    32341.00            32341.00
# mean                 48.48                      771.50                2.19
# std                  10.25                      635.12                1.74
# min                   5.00                        4.00                1.00
# 25%                  42.00                      339.00                1.00
# 50%                  51.00                      595.00                1.00
# 75%                  57.00                      972.00                3.00
# max                  76.00                     3992.00               20.00
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count          32949.00           32949.00           32949.00
# mean            2276.47              30.82              16.94
# std             4282.04              16.91              13.64
# ...

# %%
df7.isnull().sum()
#product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, poseen 610 valores nulos cada una
#product_weight_g, product_length_cm, product_height_cm, product_width_cm poseen 2 valores nulos cada una
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df7.duplicated().sum()
# Out:
# 0

# %%
df7.nunique()
# Out:
# product_id                    32951
# product_category_name            73
# product_name_lenght              66
# product_description_lenght     2960
# product_photos_qty               19
# product_weight_g               2204
# product_length_cm                99
# product_height_cm               102
# product_width_cm                 95
# dtype: int64

# %%
df7.drop_duplicates(inplace=False)
#El método df7.drop_duplicates(inplace=False) en Python crea una nueva copia del DataFrame df7 sin filas duplicadas y no modifica el DataFrame original.
#El argumento inplace=False indica que los cambios no se aplicarán al DataFrame original, sino que se devolverá un nuevo DataFrame con los duplicados eliminados.
#Si quieres guardar este nuevo DataFrame, deberás asignarlo a una nueva variable
df7_sin_duplicados = df7.drop_duplicates(inplace=False)

# %%
tipos_de_variables = df7.dtypes
print(tipos_de_variables)
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %% [markdown]
# # TABLA con los criterios para GRAFICAR cada VARIABLE SEGUN SU TIPO
# ![Variables-Graficos.png](data:image/png;base64,...)

# %%
sns.countplot(y='product_category_name', data=df7)
#Este código generará un gráfico de barras donde el eje Y representa las categorías únicas de la columna ‘product_category_name’
#y el eje y muestra la cantidad de ocurrencias para cada categoría en el DataFrame df7

# Configurar el tamaño de la letra
plt.rcParams.update({'font.size': 4}) # Cambia '12' por el tamaño de letra deseado

# Configurar el tamaño del gráfico (ancho, altura)
plt.figure(figsize=(1, 16)) # Cambia '8' y '6' por las dimensiones deseadas

plt.show()

# %% [markdown]
# # CREACION de nueva columna PRODUCT_VOLUMEN a partir de:
# > product_length_cm,
#
# >product_height_cm
#
# >product_width_cm

# %% [markdown]
# 'product_volumen_cm3' Es VOLUMEN en cm3, que se obtiene del PRODUCTO entre Longitud, Altura y Ancho, que vienen expresado en cm.

# %%
df7['product_volumen_cm3']= df7['product_length_cm']*df7['product_height_cm']*df7['product_width_cm']

# %%
df7.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df7.boxplot('product_weight_g',fontsize=14, figsize=(16,2), return_type='axes', vert=False )
# Out:
# <Axes: >

# %%
df7.boxplot('product_volumen_cm3', fontsize=14, figsize=(16,2), return_type='axes', vert=False) #vert=False lo rota
# Out:
# <Axes: >

# %%
df7.boxplot(column=['product_volumen_cm3'],by='product_category_name', fontsize=8, figsize=(8,15), return_type='axes', vert=False)

# Cambiar el eje: 'vert=False' hace que el box plot sea horizontal
# Cambiar el tamaño de la figura: figsize=(ancho, alto)
#

# Mostrar el gráfico
plt.show()

# %%
df7.boxplot(column=['product_weight_g'],by='product_category_name', fontsize=8, figsize=(7,16), return_type='axes', vert=False)
#df7.boxplot(column=['product_volumen_cm3'],by='product_category_name', fontsize=14, figsize=(20,80), return_type='axes', vert=False)
# Out:
# product_weight_g    Axes(0.1,0.15;0.8x0.75)
# dtype: object

# %%
sns.boxplot(x='product_category_name', y='product_weight_g', data=df7, palette='Set3')
plt.title('Categoria Por Peso de producto')
plt.suptitle('BoxPlot')
plt.xlabel('Categoria')
plt.ylabel('Peso')
plt.show()

# %%
sns.boxplot(y='product_category_name', x='product_weight_g', data=df7, palette='Set2')
plt.title('Categoria Por Peso de producto')
plt.suptitle('BoxPlot')
plt.ylabel('Categoria')
plt.xlabel('Peso')
plt.show()
# Out:
# <ipython-input-49-f76b4c52d67e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='product_category_name', x='product_weight_g', data=df7, palette='Set2')

# %% [markdown]
# # OCTAVA DATAFRAME: PRODUCTS CATEGORY NAMES
#
# VARIABLES:
#
# > 'product_category_name',
#
# > 'product_category_name_english'

# %%
del df8
url8='https://raw.githubusercontent.com/fabizap/Olist/main/product_category_name_translation.csv'
df8=pd.read_csv(url8)
df8.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df8.columns
# Out:
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
df8.shape #existen 71 nombres de categorias de producto
# Out:
# (71, 2)

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
df8.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
df8.isnull().sum() # 0 valores nulos
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
df8.duplicated().sum() #EXISTEN 0 DUPLICADOS?
# Out:
# 0

# %%
df8.nunique()
# Out:
# product_category_name            71
# product_category_name_english    71
# dtype: int64

# %%
df8.dtypes
# Out:
# product_category_name            object
# product_category_name_english    object
# dtype: object

# %% [markdown]
# # NOVENA DATAFRAME: GEOLOCATION _dataset.
#
# ---
# VARIABLES:
#
# >'geolocation_zip_code_prefix',
#
# >'geolocation_lat',
#
# >'geolocation_lng',
#
# >'geolocation_city',
#
# >'geolocation_state

# %%
df9.columns

# %%
from google.colab import files
uploaded = files.upload()

# %%
import io

# %%
df9 = pd.read_csv("/content/olist_geolocation_dataset.csv")

# %%
df9.head()

# %%
print(dir())

# %%
# %who

# %%
df9.shape

# %%
df9.info()

# %%
df9.isnull().sum()

# %%
df9.duplicated().sum() #EXISTEN 261.831 DUPLICADOS?
# Out:
# 261831

# %%
df9.describe().round(3)

# %%
df9.nunique() #devuelve la cantidad de valores únicos en cada columna
#existen 19015 codigos postales?, 8011 ciudades? y 27 estados?

# %% [markdown]
# promt: (en caso que el df9 contenga datos de ciudades qeu no necesito) como debo hacer el codigo en python, si tengo dos dataframes y quiero que me quede un solo dataframe que contenga unicamente los datos que yo elija de una de las columnas

# %%
df9_limpio=df9.drop_duplicates(subset=['geolocation_city'],  keep='first', inplace=False)
df9_limpio.shape
# Out:
# (8011, 5)

# %%
df9.duplicated('geolocation_city').sum() #como se interpreta? tenemos 992152 datos duplicados/repetidos?
# Out:
# 992152

# %%
df9.duplicated(subset=['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state'])
df9[df9.duplicated(subset=['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state'])]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# ...

# %%
df9[df9.duplicated('geolocation_city')]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# 6                               1047       -23.546273       -46.641225
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 1              sao paulo                SP
# ...
